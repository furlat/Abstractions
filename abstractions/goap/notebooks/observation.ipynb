# %%
from typing import Optional, Tuple, List, Dict, Any, Union
from abstractions.goap.shapes import Shadow
from abstractions.goap.gridmap import GridMap
from abstractions.goap.nodes import Node, GameEntity, BlocksMovement, BlocksLight
from abstractions.goap.spatial import WalkableGraph
from abstractions.goap.interactions import Character, Door, Key, Treasure, Floor, Wall, InanimateEntity, IsPickupable, TestItem, OpenAction, CloseAction, UnlockAction, LockAction, PickupAction, DropAction, MoveStep
from abstractions.goap.game.main import generate_dungeon
from abstractions.goap.language_state import ObservationState, ActionState, StrActionConverter
from abstractions.goap.payloads import ActionsPayload, ActionInstance, ActionResult





# Example usage
grid_map = GridMap(width=10, height=10)
grid_map.register_actions([MoveStep, PickupAction, DropAction, OpenAction, CloseAction, UnlockAction, LockAction])
room_width, room_height = 6, 6
character, door, key, treasure = generate_dungeon(grid_map, room_width, room_height)
grid_map.generate_entity_type_map()

config = {
    "character_summary": True,
    "visibility_matrix": True,
    "movement_matrix": True,
    "immediate_neighbors": True,
    "node_equivalence_classes": True,
    "living_entities": True,
    "movement_sub_goal": True,
    "attribute_summary": True,
    "pathfinding_information": True,
    "cognitive_insights": True
}

observation_state = ObservationState(character_id=character.id, config=config)
shadow = grid_map.get_shadow(character.node, max_radius=10)
observation_message = observation_state.generate(shadow)
# print(observation_message)

# Convert action string to payload
payload_converter = StrActionConverter(grid_map)
action_string = "South MoveStep Floor"
actions_payload = payload_converter.convert_action_string(action_string, character.id)

if isinstance(actions_payload, ActionsPayload):
    # Execute the action
    actions_results = grid_map.apply_actions_payload(actions_payload)

    # Analyze the action result
    if actions_results.results:
        action_result = actions_results.results[0]
        text_result_analyzer = ActionState(action_result)
        analysis = text_result_analyzer.generate_analysis()
        print(analysis)
    else:
        print("No action results found.")
else:
    print(f"Error: {actions_payload}")

# Convert an invalid action string to payload
invalid_action_string = "InvalidDirection InvalidAction InvalidTarget"
invalid_actions_payload = payload_converter.convert_action_string(invalid_action_string, character.id)

if isinstance(invalid_actions_payload, ActionsPayload):
    # Execute the action
    invalid_actions_results = grid_map.apply_actions_payload(invalid_actions_payload)

    # Analyze the action result
    if invalid_actions_results.results:
        invalid_action_result = invalid_actions_results.results[0]
        invalid_text_result_analyzer = ActionState(invalid_action_result)
        invalid_analysis = invalid_text_result_analyzer.generate_analysis()
        print(invalid_analysis)
    else:
        print("No action results found.")
else:
    print(f"Error: {invalid_actions_payload}")

#now correct action having effect on the North MoveStep Floor
action_string = "North MoveStep Floor"
actions_payload = payload_converter.convert_action_string(action_string, character.id)

if isinstance(actions_payload, ActionsPayload):
    # Execute the action
    actions_results = grid_map.apply_actions_payload(actions_payload)

    # Analyze the action result
    if actions_results.results:
        action_result = actions_results.results[0]
        text_result_analyzer = ActionState(action_result)
        analysis = text_result_analyzer.generate_analysis()
        print(analysis)
    else:
        print("No action results found.")
else:
    print(f"Error: {actions_payload}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 from typing import Optional, Tuple, List, Dict, Any, Union
#       2 from abstractions.goap.shapes import Shadow
# ----> 3 from abstractions.goap.gridmap import GridMap
#       4 from abstractions.goap.nodes import Node, GameEntity, BlocksMovement, BlocksLight
#       5 from abstractions.goap.spatial import WalkableGraph
#
# File c:\users\tommaso\documents\dev\abstractions\abstractions\goap\gridmap.py:7
#       5 from abstractions.goap.nodes import Node, GameEntity, Position
#       6 from abstractions.goap.actions import Action
# ----> 7 from abstractions.goap.payloads import ActionsPayload, ActionInstance, SummarizedActionPayload, ActionResult, ActionsResults
#       8 from abstractions.goap.errors import ActionConversionError, AmbiguousEntityError
#       9 from abstractions.goap.spatial import VisibilityGraph, WalkableGraph, PathDistanceResult, shadow_casting, dijkstra, a_star, line_of_sight
#
# File c:\users\tommaso\documents\dev\abstractions\abstractions\goap\payloads.py:37
#      34             self.results = ActionsResults(results=[])
#      35         self.results.results.append(result)
# ---> 37 class StrActionConverter:
#      38     def __init__(self, grid_map: GridMap):
#      39         self.grid_map = grid_map
#
# File c:\users\tommaso\documents\dev\abstractions\abstractions\goap\payloads.py:38, in StrActionConverter()
#      37 class StrActionConverter:
# ---> 38     def __init__(self, grid_map: GridMap):
#      39         self.grid_map = grid_map
#      41     def convert_action_string(self, action_string: str, character_id: str) -> Union[ActionsPayload, str]:
#
# NameError: name 'GridMap' is not defined

# %%
from typing import Optional, Tuple, List, Dict, Any
from abstractions.goap.shapes import Shadow
from abstractions.goap.gridmap import GridMap
from abstractions.goap.nodes import Node, GameEntity, BlocksMovement, BlocksLight
from abstractions.goap.spatial import WalkableGraph
from abstractions.goap.interactions import Character, Door, Key, Treasure, Floor, Wall, InanimateEntity, IsPickupable, TestItem, OpenAction, CloseAction, UnlockAction, LockAction, PickupAction, DropAction, MoveStep
from abstractions.goap.game.main import generate_dungeon

from abstractions.goap.language_state import ObservationState

# Example usage
grid_map = GridMap(width=10, height=10)
grid_map.register_actions([MoveStep, PickupAction, DropAction, OpenAction, CloseAction, UnlockAction, LockAction])
room_width, room_height = 6, 6
character, door, key, treasure = generate_dungeon(grid_map, room_width, room_height)
grid_map.generate_entity_type_map()

config = {
    "character_summary": True,
    "visibility_matrix": True,
    "movement_matrix": True,
    "immediate_neighbors": True,
    "node_equivalence_classes": True,
    "living_entities": True,
    "movement_sub_goal": True,
    "attribute_summary": True,
    "pathfinding_information": True,
    "cognitive_insights": True
}

observation_state = ObservationState(character_id=character.id, config=config)
shadow = grid_map.get_shadow(character.node, max_radius=10)
observation_message = observation_state.generate(shadow)
print(observation_message)
# Out:
# Updating block attributes... for door
# # Introduction
# This observation represents the current state of the game world from the character's perspective. It includes the following sections:
#
# - Character Summary: Provides an overview of the character's position and key attributes.
# - Visibility Matrix: Generates a matrix representing whether know allows raypath to cross them or not.
# - Movement Matrix: Generates a matrix representing whether the node is walkable.
# - Immediate Neighbors: Describes the 3x3 grid surrounding the character, including the node status and the entities present in each cell.
# - Node Equivalence Classes: Groups similar nodes into equivalence classes based on the combination of entities they contain and their attributes, excluding living entities.
# - Living Entities: Provides information about the living entities in the visible area, excluding the character.
# - Movement Sub Goal: Specifies the character's current movement sub-goal, including the target position and a brief description.
# - Attribute Summary: Summarizes the blocking properties of nodes in the visible area and their corresponding equivalence classes, ignoring living entities.
# - Pathfinding Information: Generates pathfinding information for paths with length greater than 1.
# - Cognitive Insights: Offers high-level observations and insights about the game world and the character's current situation.
# # Character Summary
# Position: (5, 1)
# Key Attributes:
#   - AttackPower: 10
#   - Health: 100
#   - MaxHealth: 100
#   - CanAct: True
#
#
# # Nodes Allowing Light Matrix (10x10 Grid)
# v v v v v v v v v v
# v v v v v c v v v v
# v v ? x x x x x ? v
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
#
# # Nodes Allowing Movement Matrix (10x10 Grid)
# v v v v v v v v v v
# v v v v v c v v v v
# v v ? x x x x x ? v
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
#
# # Path Matrix (10x10 Grid)
# 5 4 3 2 1 1 1 2 3 4
# 5 4 3 2 1 c 1 2 3 4
# 5 4 ? x x x x x ? 4
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
# ? ? ? ? ? ? ? ? ? ?
#
# # Immediate Neighbors (3x3 Grid)
# - NW (4, 0): Node (Passable), Entities: ['Floor']
# - N (5, 0): Node (Passable), Entities: ['Floor']
# - NE (6, 0): Node (Passable), Entities: ['Floor']
# - W (4, 1): Node (Passable), Entities: ['Floor']
# - C (5, 1): Node (Passable), Entities: ['Character', 'Floor']
# - E (6, 1): Node (Passable), Entities: ['Floor']
# - SW (4, 2): Node (Blocks Movement, Blocks Light), Entities: ['Wall', 'Floor']
# - S (5, 2): Node (Blocks Movement, Blocks Light), Entities: ['Floor', 'Door (Open: False, Locked: True, Required Key: Golden Key)']
# - SE (6, 2): Node (Blocks Movement, Blocks Light), Entities: ['Wall', 'Floor']
#
#
# # Node Equivalence Classes
# - Floor:
#   - Positions: [(4, 0), (3, 1), (5, 1), (9, 2), (8, 0), (0, 2), (1, 0), (7, 1), (3, 0), (5, 0), (9, 1), (0, 1), (1, 2), (2, 1), (6, 1), (7, 0), (4, 1), (9, 0), (8, 1), (0, 0), (1, 1), (2, 0), (6, 0)]
#   - Floor Attributes:
#     - BlocksLight: False
#     - BlocksMovement: False
#     - Material:
# - Floor, Wall:
#   - Positions: [(6, 2), (4, 2), (3, 2), (7, 2)]
#   - Floor Attributes:
#     - BlocksLight: False
#     - BlocksMovement: False
#     - Material:
#   - Wall Attributes:
#     - BlocksLight: True
#     - BlocksMovement: True
#     - Material:
# - Door, Floor:
#   - Positions: [(5, 2)]
#   - Door Attributes:
#     - BlocksLight: True
#     - BlocksMovement: True
#     - Material:
#     - Open: False
#     - is_locked: True
#     - required_key: Golden Key
#   - Floor Attributes:
#     - BlocksLight: False
#     - BlocksMovement: False
#     - Material:
#
#
# # Living Entities
# - Player (ID: 16bea4aa-0aea-4a35-a761-4f76b8359214, Position: (5, 1))
#   - Attributes:
#     - blocks_movement: False
#     - blocks_light: False
#     - health: 100
#     - max_health: 100
#     - attack_power: 10
#     - can_act: True
#
#
# # Movement Sub-Goal
# Movement Sub-Goal: Not implemented yet.
#
# # Attribute Summary
# # Nodes Spatial Attributes Summary (Ignoring Living Entities)
# - Walkable and Visible: 23 nodes
#   - Equivalence Class: [Floor (Material: )]
# - Walkable and Not Visible: 0 nodes
#   - Equivalence Classes: None
# - Not Walkable and Visible: 0 nodes
#   - Equivalence Classes: None
# - Not Walkable and Not Visible: 5 nodes
#   - Equivalence Class: [Wall (Material: ), Floor (Material: )]
#   - Equivalence Class: [Door (Material: , Open: False, is_locked: True, required_key: Golden Key), Floor (Material: )]
#
#
# # Pathfinding Information
# - Path to (3, 1): (5, 1) -> (4, 1) -> (3, 1)
# - Path to (9, 2): (5, 1) -> (6, 1) -> (7, 1) -> (8, 2) -> (9, 2)
# - Path to (8, 0): (5, 1) -> (6, 0) -> (7, 0) -> (8, 0)
# - Path to (0, 2): (5, 1) -> (4, 1) -> (3, 1) -> (2, 1) -> (1, 2) -> (0, 2)
# - Path to (1, 0): (5, 1) -> (4, 0) -> (3, 0) -> (2, 0) -> (1, 0)
# - Path to (7, 1): (5, 1) -> (6, 1) -> (7, 1)
# - Path to (3, 0): (5, 1) -> (4, 0) -> (3, 0)
# - Path to (9, 1): (5, 1) -> (6, 1) -> (7, 1) -> (8, 1) -> (9, 1)
# - Path to (0, 1): (5, 1) -> (4, 1) -> (3, 1) -> (2, 1) -> (1, 1) -> (0, 1)
# - Path to (1, 2): (5, 1) -> (4, 1) -> (3, 1) -> (2, 1) -> (1, 2)
# - Path to (2, 1): (5, 1) -> (4, 1) -> (3, 1) -> (2, 1)
# - Path to (7, 0): (5, 1) -> (6, 0) -> (7, 0)
# - Path to (9, 0): (5, 1) -> (6, 0) -> (7, 0) -> (8, 0) -> (9, 0)
# - Path to (8, 1): (5, 1) -> (6, 1) -> (7, 1) -> (8, 1)
# - Path to (0, 0): (5, 1) -> (4, 0) -> (3, 0) -> (2, 0) -> (1, 0) -> (0, 0)
# - Path to (1, 1): (5, 1) -> (4, 1) -> (3, 1) -> (2, 1) -> (1, 1)
# - Path to (2, 0): (5, 1) -> (4, 0) -> (3, 0) -> (2, 0)
#
#
# # Cognitive Insights
# Cognitive Insights: Not implemented yet.

# %%
b = Character()

# %%
b.__class__.__name__
# Out:
# 'Character'
