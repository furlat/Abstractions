# %%
import pygame
from abstractions.goap.gridmap import GridMap
from abstractions.goap.nodes import Node, GameEntity, BlocksMovement, BlocksLight
from abstractions.goap.spatial import WalkableGraph
from abstractions.goap.interactions import Character, Door, Key, Treasure, Floor, Wall, InanimateEntity, IsPickupable, TestItem, OpenAction, CloseAction, UnlockAction, LockAction, PickupAction, DropAction, MoveStep
from abstractions.goap.game.main import generate_dungeon


def debug_walkable_graph(grid_map: GridMap):
    print("Debugging Walkable Graph...")
    
    # Get the walkable graph
    walkable_graph = grid_map.get_walkable_graph()
    
    # Print the walkable matrix
    print("Walkable Matrix:")
    for row in walkable_graph.walkable_matrix:
        print(row)
    
    # Check if the walkable matrix matches the node's blocks_movement attribute
    print("Checking Node's blocks_movement attribute...")
    for x in range(grid_map.width):
        for y in range(grid_map.height):
            node = grid_map.get_node((x, y))
            print(f"Node ({x}, {y}):")
            print(f"  Entities: {[entity.__class__.__name__ for entity in node.entities]}")
            print(f"  Blocks Movement: {[entity.blocks_movement.value for entity in node.entities]}")
            if node.blocks_movement != (not walkable_graph.walkable_matrix[y][x]):
                print(f"  Mismatch found:")
                print(f"    Node blocks_movement: {node.blocks_movement}")
                print(f"    Walkable matrix value: {walkable_graph.walkable_matrix[y][x]}")
                
                # Fix the node's blocks_movement attribute
                node.blocks_movement = not walkable_graph.walkable_matrix[y][x]
                print(f"    Fixed node blocks_movement: {node.blocks_movement}")
    
    print("Debugging complete.")

# Usage example
grid_map = GridMap(width=10, height=10)
grid_map.register_actions([MoveStep, PickupAction, DropAction, OpenAction, CloseAction, UnlockAction, LockAction])
room_width, room_height = 6, 6
character, door, key, treasure = generate_dungeon(grid_map, room_width, room_height)

# Generate the entity type map
grid_map.generate_entity_type_map()

# Debug the walkable graph
debug_walkable_graph(grid_map)
# Out:
# pygame-ce 2.4.1 (SDL 2.28.5, Python 3.10.6)
# Updating block attributes... for door
# Debugging Walkable Graph...
# Walkable Matrix:
# [True, True, True, True, True, True, True, True, True, True]
# [True, True, True, True, True, True, True, True, True, True]
# [True, True, False, False, False, False, False, False, True, True]
# [True, True, False, True, True, True, True, False, True, True]
# [True, True, False, True, True, True, True, False, True, True]
# [True, True, False, True, True, True, True, False, True, True]
# [True, True, False, True, True, True, True, False, True, True]
# [True, True, False, False, False, False, False, False, True, True]
# [True, True, True, True, True, True, True, True, True, True]
# [True, True, True, True, True, True, True, True, True, True]
# Checking Node's blocks_movement attribute...
# Node (0, 0):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='7e7134b6-1246-4d24-bb49-4c19e9790a5c' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (0, 1):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='22d28347-1636-4cc3-b37b-7e21217fa063' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (0, 2):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='9f4eb565-2ef9-472c-84ba-bd251bdcd5e2' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (0, 3):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='7de4ae0c-7e20-425f-b800-5fc591457347' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (0, 4):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='8c657d2d-0fff-4a60-8b0f-2c812a0c1002' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (0, 5):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='d607267b-8239-4da0-be77-e96144102a4a' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (0, 6):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='dc277a5b-724f-4555-9908-11dc4cfbf28b' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (0, 7):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='4ee54f89-3bd1-41fb-ad0c-fb1505986582' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (0, 8):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='3d15a561-d6be-4721-b1ff-ff1e8a4db9f2' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (0, 9):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='54965efc-14c4-48dd-aa41-93717de733f6' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (1, 0):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='ca04f4ed-812c-482a-90b1-2ebe1d46e9ad' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (1, 1):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='c0b396d0-ab7c-4dc7-9774-43b790657dab' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (1, 2):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='7d96b952-313c-4cb5-8980-9c5947b3dcaf' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (1, 3):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='492f0ed9-3f5e-471a-99cd-258fbbca7626' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (1, 4):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='d147ef79-0268-402d-aa8b-70f5f36601bf' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (1, 5):
#   Entities: ['Key', 'Floor']
#   Blocks Movement: [False, False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id='6ddfbbcd-8a3f-4491-aedb-67cb32eeae07' value=False
#     Walkable matrix value: True
#     Fixed node blocks_movement: False
# Node (1, 6):
#   Entities: ['Floor']
#   Blocks Movement: [False]
#   Mismatch found:
#     Node blocks_movement: name='BlocksMovement' id