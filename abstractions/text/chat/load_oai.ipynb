# %%
from typing import Any, Dict, List, Optional, get_args, get_origin, get_type_hints, Union, Annotated
from pydantic import BaseModel, ValidationError, validator , model_validator, field_validator
from pydantic.fields import Field
from pydantic.functional_validators import AfterValidator
from graphviz import Digraph

# %%
file_url = r"C:\Users\Tommaso\Documents\Dev\Abstractions\data\conversations.json"
file_url = "/Users/tommasofurlanello/Documents/Dev/Abstractions/data/conversations.json"

# %%
import json

def load_first_record(file_path):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
        if isinstance(data, list) and len(data) > 0:
            return data[0]  # Return the first item in the list
        else:
            raise ValueError("JSON is not a list or is empty")

def load_nth_record(file_path, n):
    with open(file_path, 'r', encoding='utf-8') as file:
        data = json.load(file)
        if isinstance(data, list) and len(data) > n:
            return data[n]  # Return the nth item in the list
        else:
            raise ValueError("JSON is not a list or does not have enough items")

first_record = load_first_record(file_url)

# %%
first_record
# Out:
# {'title': 'Access Denied, Master',
#  'create_time': 1710151351.377011,
#  'update_time': 1710151386.243972,
#  'mapping': {'bad6f1ec-e065-46ce-b96a-3b0dd11b6e66': {'id': 'bad6f1ec-e065-46ce-b96a-3b0dd11b6e66',
#    'message': {'id': 'bad6f1ec-e065-46ce-b96a-3b0dd11b6e66',
#     'author': {'role': 'system', 'name': None, 'metadata': {}},
#     'create_time': None,
#     'update_time': None,
#     'content': {'content_type': 'text', 'parts': ['']},
#     'status': 'finished_successfully',
#     'end_turn': True,
#     'weight': 0.0,
#     'metadata': {'is_visually_hidden_from_conversation': True},
#     'recipient': 'all'},
#    'parent': 'aaa135a9-3650-454d-9e77-4783d861c945',
#    'children': ['aaa2b64e-48b5-424a-9d94-8a554fab4981']},
#   'aaa135a9-3650-454d-9e77-4783d861c945': {'id': 'aaa135a9-3650-454d-9e77-4783d861c945',
#    'message': None,
#    'parent': None,
#    'children': ['bad6f1ec-e065-46ce-b96a-3b0dd11b6e66']},
#   'aaa2b64e-48b5-424a-9d94-8a554fab4981': {'id': 'aaa2b64e-48b5-424a-9d94-8a554fab4981',
#    'message': {'id': 'aaa2b64e-48b5-424a-9d94-8a554fab4981',
#     'author': {'role': 'user', 'name': None, 'metadata': {}},
#     'create_time': 1710151351.377609,
#     'update_time': None,
#     'content': {'content_type': 'text',
#      'parts': ['fix punctuation\nBeware of him who would deny you access to information or in his heart he thinks himself your master']},
#     'status': 'finished_successfully',
#     'end_turn': None,
#     'weight': 1.0,
#     'metadata': {'request_id': '862ab598fd880dfb-AMS',
#      'timestamp_': 'absolute',
#      'message_type': None},
#     'recipient': 'all'},
#    'parent': 'bad6f1ec-e065-46ce-b96a-3b0dd11b6e66',
#    'children': ['833b2f3a-2d4c-44a0-a83b-b17d0759bd83']},
#   '833b2f3a-2d4c-44a0-a83b-b17d0759bd83': {'id': '833b2f3a-2d4c-44a0-a83b-b17d0759bd83',
#    'message': {'id': '833b2f3a-2d4c-44a0-a83b-b17d0759bd83',
#     'author': {'role': 'assistant', 'name': None, 'metadata': {}},
#     'create_time': 1710151352.53813,
#     'update_time': None,
#     'content': {'content_type': 'text',
#      'parts': ['Beware of him who would deny you access to information, for in his heart, he thinks himself your master.']},
#     'status': 'finished_successfully',
#     'end_turn': True,
#     'weight': 1.0,
#     'metadata': {'finish_details': {'type': 'stop', 'stop_tokens': [100260]},
#      'citations': [],
#      'gizmo_id': None,
#      'is_complete': True,
#      'message_type': None,
#      'model_slug': 'gpt-4',
#      'parent_id': 'aaa2b64e-48b5-424a-9d94-8a554fab4981',
#      'request_id': '862ab598fd880dfb-AMS',
#      'timestamp_': 'absolute'},
#     'recipient': 'all'},
#    'parent': 'aaa2b64e-48b5-424a-9d94-8a554fab4981',
#    'children': ['aaa23e46-fc9a-4d88-8deb-8aac924f9aaf']},
#   'aaa23e46-fc9a-4d88-8deb-8aac924f9aaf': {'id': 'aaa23e46-fc9a-4d88-8deb-8aac924f9aaf',
#    'message': {'id': 'aaa23e46-fc9a-4d88-8deb-8aac924f9aaf',
#     'author': {'role': 'user', 'name': None, 'metadata': {}},
#     'create_time': 1710151369.098633,
#     'update_time': None,
#     'content': {'content_type': 'text',
#      'parts': ['make a depiction of the concept']},
#     'status': 'finished_successfully',
#     'end_turn': None,
#     'weight': 1.0,
#     'metadata': {'request_id': '862ab6077ff50dfb-AMS',
#      'timestamp_': 'absolute',
#      'message_type': None},
#     'recipient': 'all'},
#    'parent': '833b2f3a-2d4c-44a0-a83b-b17d0759bd83',
#    'children': ['e9846981-ef02-4446-ae3d-d1ee15295b30']},
#   'e9846981-ef02-4446-ae3d-d1ee15295b30': {'id': 'e9846981-ef02-4446-ae3d-d1ee15295b30',
#    'message': {'id': 'e9846981-ef02-4446-ae3d-d1ee15295b30',
#     'author': {'role': 'assistant', 'name': None, 'metadata': {}},
#     'create_time': 1710151386.23856,
#     'update_time': None,
#     'content': {'content_type': 'code',
#      'language': 'json',
#      'text': '{"size":"1024x1024","prompt":"A symbolic representation of the concept \'denial of information\'. Visualize a figure, a personification of authority, imposingly standing with a large lock in his hand, symbolizing the restriction of access to a giant book or archive behind him. The background is a vast library, representing knowledge, but with chains around the books. The figure is silhouetted, exuding an aura of control and dominance, embodying the idea that withholding information is a form of power. The atmosphere is slightly ominous, highlighting the theme of censorship and the struggle for freedom of information."}'},
#     'status': 'finished_successfully',
#     'end_turn': False,
#     'weight': 1.0,
#     'metadata': {'finish_details': {'type': 'stop', 'stop_tokens': [100265]},
#      'gizmo_id': None,
#      'is_complete': True,
#      'message_type': None,
#      'model_slug': 'gpt-4',
#      'parent_id': 'aaa23e46-fc9a-4d88-8deb-8aac924f9aaf',
#      'request_id': '862ab6077ff50dfb-AMS',
#      'timestamp_': 'absolute'},
#     'recipient': 'dalle.text2im'},
#    'parent': 'aaa23e46-fc9a-4d88-8deb-8aac924f9aaf',
#    'children': ['4a44c386-47a9-4179-8f35-1ba87ed3eefb']},
#   '4a44c386-47a9-4179-8f35-1ba87ed3eefb': {'id': '4a44c386-47a9-4179-8f35-1ba87ed3eefb',
#    'message': {'id': '4a44c386-47a9-4179-8f35-1ba87ed3eefb',
#     'author': {'role': 'tool', 'name': 'dalle.text2im', 'metadata': {}},
#     'create_time': 1710151386.241205,
#     'update_time': None,
#     'content': {'content_type': 'multimodal_text',
#      'parts': [{'content_type': 'image_asset_pointer',
#        'asset_pointer': 'file-service://file-Y8b29zcLOvedUkgIDh7dYuQ9',
#        'size_bytes': 506722,
#        'width': 1024,
#        'height': 1024,
#        'fovea': 512,
#        'metadata': {'dalle': {'gen_id': '9frMWMALFJ2Qokbr',
#          'prompt': "A symbolic representation of the concept 'denial of information'. Visualize a figure, a personification of authority, imposingly standing with a large lock in his hand, symbolizing the restriction of access to a giant book or archive behind him. The background is a vast library, representing knowledge, but with chains around the books. The figure is silhouetted, exuding an aura of control and dominance, embodying the idea that withholding information is a form of power. The atmosphere is slightly ominous, highlighting the theme of censorship and the struggle for freedom of information.",
#          'seed': 1619700167,
#          'serialization_title': 'DALL-E generation metadata'}}}]},
#     'status': 'finished_successfully',
#     'end_turn': None,
#     'weight': 1.0,
#     'metadata': {'message_type': None,
#      'model_slug': 'gpt-4',
#      'parent_id': 'e9846981-ef02-4446-ae3d-d1ee15295b30',
#      'request_id': '862ab6077ff50dfb-AMS',
#      'timestamp_': 'absolute'},
#     'recipient': 'all'},
#    'parent': 'e9846981-ef02-4446-ae3d-d1ee15295b30',
#    'children': ['3bfa6eae-c452-4f74-89de-395569545ce0']},
#   '3bfa6eae-c452-4f74-89de-395569545ce0': {'id': '3bfa6eae-c452-4f74-89de-395569545ce0',
#    'message': {'id': '3bfa6eae-c452-4f74-89de-395569545ce0',
#     'author': {'role': 'tool', 'name': 'dalle.text2im', 'metadata': {}},
#     'create_time': 1710151386.241427,
#     'update_time': None,
#     'content': {'content_type': 'text',
#      'parts': ["\nDALL·E displayed 1 images. The images are already plainly visible, so don't repeat the descriptions in detail. Do not list download links as they are available in the ChatGPT UI already. The user may download the images by clicking on them, but do not mention anything about downloading to the user."]},
#     'status': 'finished_successfully',
#     'end_turn': None,
#     'weight': 1.0,
#     'metadata': {'message_type': None,
#      'model_slug': 'gpt-4',
#      'parent_id': '4a44c386-47a9-4179-8f35-1ba87ed3eefb',
#      'request_id': '862ab6077ff50dfb-AMS',
#      'timestamp_': 'absolute'},
#     'recipient': 'all'},
#    'parent': '4a44c386-47a9-4179-8f35-1ba87ed3eefb',
#    'children': ['bee92103-ed0b-4400-80dc-53c98b100bbc']},
#   'bee92103-ed0b-4400-80dc-53c98b100bbc': {'id': 'bee92103-ed0b-4400-80dc-53c98b100bbc',
#    'message': {'id': 'bee92103-ed0b-4400-80dc-53c98b100bbc',
#     'author': {'role': 'assistant', 'name': None, 'metadata': {}},
#     'create_time': 1710151386.241561,
#     'update_time': None,
#     'content': {'content_type': 'text',
#      'parts': ['Here is a depiction of the concept representing the denial of information, visualized through a symbolic representation.']},
#     'status': 'finished_successfully',
#     'end_turn': True,
#     'weight': 1.0,
#     'metadata': {'finish_details': {'type': 'stop', 'stop_tokens': [100260]},
#      'citations': [],
#      'gizmo_id': None,
#      'is_complete': True,
#      'message_type': None,
#      'model_slug': 'gpt-4',
#      'parent_id': '3bfa6eae-c452-4f74-89de-395569545ce0',
#      'request_id': '862ab6077ff50dfb-AMS',
#      'timestamp_': 'absolute'},
#     'recipient': 'all'},
#    'parent': '3bfa6eae-c452-4f74-89de-395569545ce0',
#    'children': []}},
#  'moderation_results': [],
#  'current_node': 'bee92103-ed0b-4400-80dc-53c98b100bbc',
#  'plugin_ids': None,
#  'conversation_id': '78a511be-2808-44b0-9600-99436d422b98',
#  'conversation_template_id': None,
#  'gizmo_id': None,
#  'is_archived': False,
#  'safe_urls': [],
#  'id': '78a511be-2808-44b0-9600-99436d422b98'}

# %%
class Author(BaseModel):
    role: str
    name: Optional[str] = None
    metadata: Dict[str, Any] = {}

class Content(BaseModel):
    content_type: str
    parts: Optional[Union[List[Union[str, Dict[str, Any]]], Dict[str, Any]]] = None
    language: Optional[str] = None
    text: Optional[str] = None

    @field_validator('parts', mode= 'before')
    def validate_parts(cls, v):
        if isinstance(v, dict):
            return [v]  # Wrap in a list if it's a dict
        return v
    def get_message_content(self):
    # Check if text is provided
        content = self
        if content.text:
            return content.text
        # If text is None, try to get content from parts
        elif content.parts:
            # If parts is a list, we concatenate items or get the text from dict
            if isinstance(content.parts, list):
                # Concatenate list items if they are strings, or stringify them if they are dicts
                return ' '.join(str(part) if isinstance(part, dict) else part for part in content.parts)
            # If parts is a dict, we convert it to string
            elif isinstance(content.parts, dict):
                return str(content.parts)
        return 'No message'

class Message(BaseModel):
    id: str
    author: Optional[Author] = None
    create_time: Optional[float] = None
    update_time: Optional[float] = None
    content: Optional[Content] = None
    status: str
    end_turn: Optional[bool] = None
    weight: float
    metadata: Dict[str, Any] = {}
    recipient: str

# %%
from typing import List, Optional
from pydantic import BaseModel



class Node(BaseModel):
    id: str
    message: Optional[Message] = None
    parent: Optional[str] = None
    children: List[str] = []

    def is_leaf(self) -> bool:
        return len(self.children) == 0

    def is_root(self) -> bool:
        return self.parent is None

    def is_linear(self) -> bool:
        return len(self.children) <= 1 and (self.parent is None or self.parent.children == 1)

class Conversation(BaseModel):
    title: str
    create_time: float
    update_time: float
    mapping: Dict[str, Node]
    moderation_results: List[Any] = []
    current_node: str
    plugin_ids: Optional[Any] = None
    conversation_id: str
    conversation_template_id: Optional[Any] = None
    gizmo_id: Optional[Any] = None
    is_archived: bool
    safe_urls: List[Any] = []
    id: str

    def extract_all_linearized_conversations(self) -> List['LinearConversation']:
        def build_linear_conversations(node_id: str, current_path: Dict[str, Node], depth=0):
            node = self.mapping[node_id]
            new_node = node.model_copy(deep=True)
            new_node.children = new_node.children[:1]  # Keep only the first child to ensure linearity

            # Update the current path with the new linear node
            new_path = {**current_path, new_node.id: new_node}

            if not new_node.children:
                # Leaf node, store the current path as a linear conversation
                linear_conversations.append(LinearConversation(**{**self.model_dump(), "mapping": new_path}))
            else:
                # Recursively build the conversation for the next node in the path
                build_linear_conversations(new_node.children[0], new_path, depth + 1)

            # If the original node had multiple children, start new paths for each
            if len(node.children) > 1:
                for child_id in node.children[1:]:
                    build_linear_conversations(child_id, current_path, depth + 1)

        linear_conversations = []
        for node_id, node in self.mapping.items():
            if not node.parent:
                build_linear_conversations(node_id, {})

        return linear_conversations
    
    def visualize_conversation(self, filename: str = 'conversation_graph'):
        graph = Digraph(comment=self.title)

        def add_nodes_and_edges(node_id: str):
            node = self.mapping[node_id]
            if node.message and node.message.author:
                author_role = node.message.author.role  # User or Assistant
                # Use the get_message_content method to retrieve the message content
                message_content = node.message.content.get_message_content() if node.message.content else "No content"
                label = f"{author_role}: {message_content}"
            else:
                label = "No message"

            graph.node(node_id, label=label)

            for child_id in node.children:
                graph.edge(node_id, child_id)
                add_nodes_and_edges(child_id)

        for node_id, node in self.mapping.items():
            if node.is_root():
                add_nodes_and_edges(node_id)

        graph.render(filename, view=True, format='png')

    
def validate_single_child_node(node: Node) -> Node:
    if len(node.children) > 1:
        raise ValueError("Node has multiple children, not suitable for LinearConversation.")
    return node

NodeWithSingleChild = Annotated[Node, AfterValidator(validate_single_child_node)]

class LinearConversation(Conversation):
    mapping: Dict[str, NodeWithSingleChild]

    def __init__(self, **data: Any):
        super().__init__(**data)

# %%
first_record
# Out:
# {'title': 'Access Denied, Master',
#  'create_time': 1710151351.377011,
#  'update_time': 1710151386.243972,
#  'mapping': {'bad6f1ec-e065-46ce-b96a-3b0dd11b6e66': {'id': 'bad6f1ec-e065-46ce-b96a-3b0dd11b6e66',
#    'message': {'id': 'bad6f1ec-e065-46ce-b96a-3b0dd11b6e66',
#     'author': {'role': 'system', 'name': None, 'metadata': {}},
#     'create_time': None,
#     'update_time': None,
#     'content': {'content_type': 'text', 'parts': ['']},
#     'status': 'finished_successfully',
#     'end_turn': True,
#     'weight': 0.0,
#     'metadata': {'is_visually_hidden_from_conversation': True},
#     'recipient': 'all'},
#    'parent': 'aaa135a9-3650-454d-9e77-4783d861c945',
#    'children': ['aaa2b64e-48b5-424a-9d94-8a554fab4981']},
#   'aaa135a9-3650-454d-9e77-4783d861c945': {'id': 'aaa135a9-3650-454d-9e77-4783d861c945',
#    'message': None,
#    'parent': None,
#    'children': ['bad6f1ec-e065-46ce-b96a-3b0dd11b6e66']},
#   'aaa2b64e-48b5-424a-9d94-8a554fab4981': {'id': 'aaa2b64e-48b5-424a-9d94-8a554fab4981',
#    'message': {'id': 'aaa2b64e-48b5-424a-9d94-8a554fab4981',
#     'author': {'role': 'user', 'name': None, 'metadata': {}},
#     'create_time': 1710151351.377609,
#     'update_time': None,
#     'content': {'content_type': 'text',
#      'parts': ['fix punctuation\nBeware of him who would deny you access to information or in his heart he thinks himself your master']},
#     'status': 'finished_successfully',
#     'end_turn': None,
#     'weight': 1.0,
#     'metadata': {'request_id': '862ab598fd880dfb-AMS',
#      'timestamp_': 'absolute',
#      'message_type': None},
#     'recipient': 'all'},
#    'parent': 'bad6f1ec-e065-46ce-b96a-3b0dd11b6e66',
#    'children': ['833b2f3a-2d4c-44a0-a83b-b17d0759bd83']},
#   '833b2f3a-2d4c-44a0-a83b-b17d0759bd83': {'id': '833b2f3a-2d4c-44a0-a83b-b17d0759bd83',
#    'message': {'id': '833b2f3a-2d4c-44a0-a83b-b17d0759bd83',
#     'author': {'role': 'assistant', 'name': None, 'metadata': {}},
#     'create_time': 1710151352.53813,
#     'update_time': None,
#     'content': {'content_type': 'text',
#      'parts': ['Beware of him who would deny you access to information, for in his heart, he thinks himself your master.']},
#     'status': 'finished_successfully',
#     'end_turn': True,
#     'weight': 1.0,
#     'metadata': {'finish_details': {'type': 'stop', 'stop_tokens': [100260]},
#      'citations': [],
#      'gizmo_id': None,
#      'is_complete': True,
#      'message_type': None,
#      'model_slug': 'gpt-4',
#      'parent_id': 'aaa2b64e-48b5-424a-9d94-8a554fab4981',
#      'request_id': '862ab598fd880dfb-AMS',
#      'timestamp_': 'absolute'},
#     'recipient': 'all'},
#    'parent': 'aaa2b64e-48b5-424a-9d94-8a554fab4981',
#    'children': ['aaa23e46-fc9a-4d88-8deb-8aac924f9aaf']},
#   'aaa23e46-fc9a-4d88-8deb-8aac924f9aaf': {'id': 'aaa23e46-fc9a-4d88-8deb-8aac924f9aaf',
#    'message': {'id': 'aaa23e46-fc9a-4d88-8deb-8aac924f9aaf',
#     'author': {'role': 'user', 'name': None, 'metadata': {}},
#     'create_time': 1710151369.098633,
#     'update_time': None,
#     'content': {'content_type': 'text',
#      'parts': ['make a depiction of the concept']},
#     'status': 'finished_successfully',
#     'end_turn': None,
#     'weight': 1.0,
#     'metadata': {'request_id': '862ab6077ff50dfb-AMS',
#      'timestamp_': 'absolute',
#      'message_type': None},
#     'recipient': 'all'},
#    'parent': '833b2f3a-2d4c-44a0-a83b-b17d0759bd83',
#    'children': ['e9846981-ef02-4446-ae3d-d1ee15295b30']},
#   'e9846981-ef02-4446-ae3d-d1ee15295b30': {'id': 'e9846981-ef02-4446-ae3d-d1ee15295b30',
#    'message': {'id': 'e9846981-ef02-4446-ae3d-d1ee15295b30',
#     'author': {'role': 'assistant', 'name': None, 'metadata': {}},
#     'create_time': 1710151386.23856,
#     'update_time': None,
#     'content': {'content_type': 'code',
#      'language': 'json',
#      'text': '{"size":"1024x1024","prompt":"A symbolic representation of the concept \'denial of information\'. Visualize a figure, a personification of authority, imposingly standing with a large lock in his hand, symbolizing the restriction of access to a giant book or archive behind him. The background is a vast library, representing knowledge, but with chains around the books. The figure is silhouetted, exuding an aura of control and dominance, embodying the idea that withholding information is a form of power. The atmosphere is slightly ominous, highlighting the theme of censorship and the struggle for freedom of information."}'},
#     'status': 'finished_successfully',
#     'end_turn': False,
#     'weight': 1.0,
#     'metadata': {'finish_details': {'type': 'stop', 'stop_tokens': [100265]},
#      'gizmo_id': None,
#      'is_complete': True,
#      'message_type': None,
#      'model_slug': 'gpt-4',
#      'parent_id': 'aaa23e46-fc9a-4d88-8deb-8aac924f9aaf',
#      'request_id': '862ab6077ff50dfb-AMS',
#      'timestamp_': 'absolute'},
#     'recipient': 'dalle.text2im'},
#    'parent': 'aaa23e46-fc9a-4d88-8deb-8aac924f9aaf',
#    'children': ['4a44c386-47a9-4179-8f35-1ba87ed3eefb']},
#   '4a44c386-47a9-4179-8f35-1ba87ed3eefb': {'id': '4a44c386-47a9-4179-8f35-1ba87ed3eefb',
#    'message': {'id': '4a44c386-47a9-4179-8f35-1ba87ed3eefb',
#     'author': {'role': 'tool', 'name': 'dalle.text2im', 'metadata': {}},
#     'create_time': 1710151386.241205,
#     'update_time': None,
#     'content': {'content_type': 'multimodal_text',
#      'parts': [{'content_type': 'image_asset_pointer',
#        'asset_pointer': 'file-service://file-Y8b29zcLOvedUkgIDh7dYuQ9',
#        'size_bytes': 506722,
#        'width': 1024,
#        'height': 1024,
#        'fovea': 512,
#        'metadata': {'dalle': {'gen_id': '9frMWMALFJ2Qokbr',
#          'prompt': "A symbolic representation of the concept 'denial of information'. Visualize a figure, a personification of authority, imposingly standing with a large lock in his hand, symbolizing the restriction of access to a giant book or archive behind him. The background is a vast library, representing knowledge, but with chains around the books. The figure is silhouetted, exuding an aura of control and dominance, embodying the idea that withholding information is a form of power. The atmosphere is slightly ominous, highlighting the theme of censorship and the struggle for freedom of information.",
#          'seed': 1619700167,
#          'serialization_title': 'DALL-E generation metadata'}}}]},
#     'status': 'finished_successfully',
#     'end_turn': None,
#     'weight': 1.0,
#     'metadata': {'message_type': None,
#      'model_slug': 'gpt-4',
#      'parent_id': 'e9846981-ef02-4446-ae3d-d1ee15295b30',
#      'request_id': '862ab6077ff50dfb-AMS',
#      'timestamp_': 'absolute'},
#     'recipient': 'all'},
#    'parent': 'e9846981-ef02-4446-ae3d-d1ee15295b30',
#    'children': ['3bfa6eae-c452-4f74-89de-395569545ce0']},
#   '3bfa6eae-c452-4f74-89de-395569545ce0': {'id': '3bfa6eae-c452-4f74-89de-395569545ce0',
#    'message': {'id': '3bfa6eae-c452-4f74-89de-395569545ce0',
#     'author': {'role': 'tool', 'name': 'dalle.text2im', 'metadata': {}},
#     'create_time': 1710151386.241427,
#     'update_time': None,
#     'content': {'content_type': 'text',
#      'parts': ["\nDALL·E displayed 1 images. The images are already plainly visible, so don't repeat the descriptions in detail. Do not list download links as they are available in the ChatGPT UI already. The user may download the images by clicking on them, but do not mention anything about downloading to the user."]},
#     'status': 'finished_successfully',
#     'end_turn': None,
#     'weight': 1.0,
#     'metadata': {'message_type': None,
#      'model_slug': 'gpt-4',
#      'parent_id': '4a44c386-47a9-4179-8f35-1ba87ed3eefb',
#      'request_id': '862ab6077ff50dfb-AMS',
#      'timestamp_': 'absolute'},
#     'recipient': 'all'},
#    'parent': '4a44c386-47a9-4179-8f35-1ba87ed3eefb',
#    'children': ['bee92103-ed0b-4400-80dc-53c98b100bbc']},
#   'bee92103-ed0b-4400-80dc-53c98b100bbc': {'id': 'bee92103-ed0b-4400-80dc-53c98b100bbc',
#    'message': {'id': 'bee92103-ed0b-4400-80dc-53c98b100bbc',
#     'author': {'role': 'assistant', 'name': None, 'metadata': {}},
#     'create_time': 1710151386.241561,
#     'update_time': None,
#     'content': {'content_type': 'text',
#      'parts': ['Here is a depiction of the concept representing the denial of information, visualized through a symbolic representation.']},
#     'status': 'finished_successfully',
#     'end_turn': True,
#     'weight': 1.0,
#     'metadata': {'finish_details': {'type': 'stop', 'stop_tokens': [100260]},
#      'citations': [],
#      'gizmo_id': None,
#      'is_complete': True,
#      'message_type': None,
#      'model_slug': 'gpt-4',
#      'parent_id': '3bfa6eae-c452-4f74-89de-395569545ce0',
#      'request_id': '862ab6077ff50dfb-AMS',
#      'timestamp_': 'absolute'},
#     'recipient': 'all'},
#    'parent': '3bfa6eae-c452-4f74-89de-395569545ce0',
#    'children': []}},
#  'moderation_results': [],
#  'current_node': 'bee92103-ed0b-4400-80dc-53c98b100bbc',
#  'plugin_ids': None,
#  'conversation_id': '78a511be-2808-44b0-9600-99436d422b98',
#  'conversation_template_id': None,
#  'gizmo_id': None,
#  'is_archived': False,
#  'safe_urls': [],
#  'id': '78a511be-2808-44b0-9600-99436d422b98'}

# %%
conversation_instance = Conversation(**first_record)
conversation_instance
# Out:
# Conversation(title='Access Denied, Master', create_time=1710151351.377011, update_time=1710151386.243972, mapping={'bad6f1ec-e065-46ce-b96a-3b0dd11b6e66': Node(id='bad6f1ec-e065-46ce-b96a-3b0dd11b6e66', message=Message(id='bad6f1ec-e065-46ce-b96a-3b0dd11b6e66', author=Author(role='system', name=None, metadata={}), create_time=None, update_time=None, content=Content(content_type='text', parts=[''], language=None, text=None), status='finished_successfully', end_turn=True, weight=0.0, metadata={'is_visually_hidden_from_conversation': True}, recipient='all'), parent='aaa135a9-3650-454d-9e77-4783d861c945', children=['aaa2b64e-48b5-424a-9d94-8a554fab4981']), 'aaa135a9-3650-454d-9e77-4783d861c945': Node(id='aaa135a9-3650-454d-9e77-4783d861c945', message=None, parent=None, children=['bad6f1ec-e065-46ce-b96a-3b0dd11b6e66']), 'aaa2b64e-48b5-424a-9d94-8a554fab4981': Node(id='aaa2b64e-48b5-424a-9d94-8a554fab4981', message=Message(id='aaa2b64e-48b5-424a-9d94-8a554fab4981', author=Author(role='user', name=None, metadata={}), create_time=1710151351.377609, update_time=None, content=Content(content_type='text', parts=['fix punctuation\nBeware of him who would deny you access to information or in his heart he thinks himself your master'], language=None, text=None), status='finished_successfully', end_turn=None, weight=1.0, metadata={'request_id': '862ab598fd880dfb-AMS', 'timestamp_': 'absolute', 'message_type': None}, recipient='all'), parent='bad6f1ec-e065-46ce-b96a-3b0dd11b6e66', children=['833b2f3a-2d4c-44a0-a83b-b17d0759bd83']), '833b2f3a-2d4c-44a0-a83b-b17d0759bd83': Node(id='833b2f3a-2d4c-44a0-a83b-b17d0759bd83', message=Message(id='833b2f3a-2d4c-44a0-a83b-b17d0759bd83', author=Author(role='assistant', name=None, metadata={}), create_time=1710151352.53813, update_time=None, content=Content(content_type='text', parts=['Beware of him who would deny you access to information, for in his heart, he thinks himself your master.'], language=None, text=None), status='finished_successfully', end_turn=True, weight=1.0, metadata={'finish_details': {'type': 'stop', 'stop_tokens': [100260]}, 'citations': [], 'gizmo_id': None, 'is_complete': True, 'message_type': None, 'model_slug': 'gpt-4', 'parent_id': 'aaa2b64e-48b5-424a-9d94-8a554fab4981', 'request_id': '862ab598fd880dfb-AMS', 'timestamp_': 'absolute'}, recipient='all'), parent='aaa2b64e-48b5-424a-9d94-8a554fab4981', children=['aaa23e46-fc9a-4d88-8deb-8aac924f9aaf']), 'aaa23e46-fc9a-4d88-8deb-8aac924f9aaf': Node(id='aaa23e46-fc9a-4d88-8deb-8aac924f9aaf', message=Message(id='aaa23e46-fc9a-4d88-8deb-8aac924f9aaf', author=Author(role='user', name=None, metadata={}), create_time=1710151369.098633, update_time=None, content=Content(content_type='text', parts=['make a depiction of the concept'], language=None, text=None), status='finished_successfully', end_turn=None, weight=1.0, metadata={'request_id': '862ab6077ff50dfb-AMS', 'timestamp_': 'absolute', 'message_type': None}, recipient='all'), parent='833b2f3a-2d4c-44a0-a83b-b17d0759bd83', children=['e9846981-ef02-4446-ae3d-d1ee15295b30']), 'e9846981-ef02-4446-ae3d-d1ee15295b30': Node(id='e9846981-ef02-4446-ae3d-d1ee15295b30', message=Message(id='e9846981-ef02-4446-ae3d-d1ee15295b30', author=Author(role='assistant', name=None, metadata={}), create_time=1710151386.23856, update_time=None, content=Content(content_type='code', parts=None, language='json', text='{"size":"1024x1024","prompt":"A symbolic representation of the concept \'denial of information\'. Visualize a figure, a personification of authority, imposingly standing with a large lock in his hand, symbolizing the restriction of access to a giant book or archive behind him. The background is a vast library, representing knowledge, but with chains around the books. The figure is silhouetted, exuding an aura of control and dominance, embodying the idea that withholding information is a form of power. The atmosphere is slightly ominous, highlighting the theme of censorship and the struggle for freedom ...

# %%
conversation_instance.visualize_conversation()

# %%
len(conversation_instance.extract_all_linearized_conversations())
# Out:
# 1

# %%
test_record = load_nth_record(file_url, 3)

# %%
test_instance = Conversation(**test_record)
print(test_instance)
print(len(test_instance.extract_all_linearized_conversations()))
# Out:
# title='Functional Criteria for Compound Order' create_time=1709851858.42512 update_time=1709852062.470933 mapping={'dc35e96e-78eb-434f-ad69-2f84416bb49c': Node(id='dc35e96e-78eb-434f-ad69-2f84416bb49c', message=Message(id='dc35e96e-78eb-434f-ad69-2f84416bb49c', author=Author(role='system', name=None, metadata={}), create_time=None, update_time=None, content=Content(content_type='text', parts=[''], language=None, text=None), status='finished_successfully', end_turn=True, weight=0.0, metadata={'is_visually_hidden_from_conversation': True}, recipient='all'), parent='aaa15694-6345-43a7-be05-1c5b4f73f9f6', children=['aaa239c1-beeb-4101-be6a-3b95dc9b0466', 'aaa2529d-3ccd-4f97-8907-35cddef7bef1', 'aaa2d260-4979-4b5d-acd7-24d658ade059', 'aaa270c8-9410-41ff-a995-8ced8fa2891c']), 'aaa15694-6345-43a7-be05-1c5b4f73f9f6': Node(id='aaa15694-6345-43a7-be05-1c5b4f73f9f6', message=None, parent=None, children=['dc35e96e-78eb-434f-ad69-2f84416bb49c']), 'aaa239c1-beeb-4101-be6a-3b95dc9b0466': Node(id='aaa239c1-beeb-4101-be6a-3b95dc9b0466', message=Message(id='aaa239c1-beeb-4101-be6a-3b95dc9b0466', author=Author(role='user', name=None, metadata={}), create_time=1709851858.426031, update_time=None, content=Content(content_type='text', parts=['find a rationale for this compound ordering \nCompound: fluoxetine hydrochloride\nCompound: labetalol\nCompound: acarbose\nCompound: nicotinic acid\nCompound: ajmaline\nCompound: carboplatin\nCompound: ranitidine\nCompound: benziodarone\nCompound: butylated hydroxyanisole\nCompound: danazol\nCompound: omeprazole\nCompound: chlormadinone\nCompound: WY-14643\nCompound: bendazac\nCompound: simvastatin\nCompound: griseofulvin\nCompound: etoposide\nCompound: nimesulide\nCompound: 2,4-dinitrophenol\nCompound: diclofenac\nCompound: tiopronin\nCompound: famotidine\nCompound: pemoline\nCompound: cyclophosphamide\nCompound: triazolam\nCompound: colchicine\nCompound: dantrolene\nCompound: perhexiline\nCompound: ethanol\nCompound: erythromycin ethylsuccinate\nCompound: lomustine\nCompound: doxorubicin\nCompound: acetamidofluorene\nCompound: tacrine\nCompound: caffeine\nCompound: captopril\nCompound: azathioprine\nCompound: flutamide\nCompound: aspirin\nCompound: carbon tetrachloride\nCompound: nitrofurazone\nCompound: nitrosodiethylamine\nCompound: chlormezanone\nCompound: moxisylyte\nCompound: isoniazid\nCompound: rotenone\nCompound: naphthyl isothiocyanate\nCompound: metformin\nCompound: theophylline\nCompound: sulfasalazine\nCompound: adapin\nCompound: nitrofurantoin\nCompound: sulindac\nCompound: cimetidine\nCompound: sulpiride\nCompound: clofibrate\nCompound: benzbromarone\nCompound: amiodarone\nCompound: rosiglitazone maleate\nCompound: hexachlorobenzene\nCompound: propranolol\nCompound: propylthiouracil\nCompound: glibenclamide\nCompound: allyl alcohol\nCompound: ethionamide\nCompound: tetracycline\nCompound: carbamazepine\nCompound: enalapril\nCompound: ethinylestradiol\nCompound: haloperidol\nCompound: bucetin\nCompound: ethionine\nCompound: methapyrilene\nCompound: methylene dianiline\nCompound: lornoxicam\nCompound: fluphenazine\nCompound: rifampicin\nCompound: methyldopa\nCompound: phenylanthranilic acid\nCompound: disulfiram\nCompound: quinidine\nCompound: ticlopidine\nCompound: puromycin aminonucleoside\nCompound: promethazine\nCompound: bromobenzene\nCompound: thioridazine\nCompound: ethambutol\nCompound: gemfibrozil\nCompound: diltiazem\nCompound: vitamin A\nCompound: ciprofloxacin\nCompound: phenobarbital\nCompound: methyltestosterone\nCompound: chlorpropamide\nCompound: ibuprofen\nCompound: nifedipine\nCompound: tolbutamide\nCompound: thioacetamide\nCompound: clomipramine\nCompound: bromoethylamine\nCompound: trimethadione\nCompound: coumarin\nCompound: meloxicam\nCompound: chlorpheniramine\nCompound: fenofibrate\nCompound: valproic acid\nCompound: acetazolamide\nCompound: terbinafine\nCompound: triamterene\nCompound: allopurinol\nCompound: amphotericin B\nCompound: desmopressin acetate\nCompound: cephal ...
# 4

# %%
test_instance.extract_all_linearized_conversations()
# Out:
# [LinearConversation(title='Functional Criteria for Compound Order', create_time=1709851858.42512, update_time=1709852062.470933, mapping={'aaa15694-6345-43a7-be05-1c5b4f73f9f6': Node(id='aaa15694-6345-43a7-be05-1c5b4f73f9f6', message=None, parent=None, children=['dc35e96e-78eb-434f-ad69-2f84416bb49c']), 'dc35e96e-78eb-434f-ad69-2f84416bb49c': Node(id='dc35e96e-78eb-434f-ad69-2f84416bb49c', message=Message(id='dc35e96e-78eb-434f-ad69-2f84416bb49c', author=Author(role='system', name=None, metadata={}), create_time=None, update_time=None, content=Content(content_type='text', parts=[''], language=None, text=None), status='finished_successfully', end_turn=True, weight=0.0, metadata={'is_visually_hidden_from_conversation': True}, recipient='all'), parent='aaa15694-6345-43a7-be05-1c5b4f73f9f6', children=['aaa239c1-beeb-4101-be6a-3b95dc9b0466']), 'aaa239c1-beeb-4101-be6a-3b95dc9b0466': Node(id='aaa239c1-beeb-4101-be6a-3b95dc9b0466', message=Message(id='aaa239c1-beeb-4101-be6a-3b95dc9b0466', author=Author(role='user', name=None, metadata={}), create_time=1709851858.426031, update_time=None, content=Content(content_type='text', parts=['find a rationale for this compound ordering \nCompound: fluoxetine hydrochloride\nCompound: labetalol\nCompound: acarbose\nCompound: nicotinic acid\nCompound: ajmaline\nCompound: carboplatin\nCompound: ranitidine\nCompound: benziodarone\nCompound: butylated hydroxyanisole\nCompound: danazol\nCompound: omeprazole\nCompound: chlormadinone\nCompound: WY-14643\nCompound: bendazac\nCompound: simvastatin\nCompound: griseofulvin\nCompound: etoposide\nCompound: nimesulide\nCompound: 2,4-dinitrophenol\nCompound: diclofenac\nCompound: tiopronin\nCompound: famotidine\nCompound: pemoline\nCompound: cyclophosphamide\nCompound: triazolam\nCompound: colchicine\nCompound: dantrolene\nCompound: perhexiline\nCompound: ethanol\nCompound: erythromycin ethylsuccinate\nCompound: lomustine\nCompound: doxorubicin\nCompound: acetamidofluorene\nCompound: tacrine\nCompound: caffeine\nCompound: captopril\nCompound: azathioprine\nCompound: flutamide\nCompound: aspirin\nCompound: carbon tetrachloride\nCompound: nitrofurazone\nCompound: nitrosodiethylamine\nCompound: chlormezanone\nCompound: moxisylyte\nCompound: isoniazid\nCompound: rotenone\nCompound: naphthyl isothiocyanate\nCompound: metformin\nCompound: theophylline\nCompound: sulfasalazine\nCompound: adapin\nCompound: nitrofurantoin\nCompound: sulindac\nCompound: cimetidine\nCompound: sulpiride\nCompound: clofibrate\nCompound: benzbromarone\nCompound: amiodarone\nCompound: rosiglitazone maleate\nCompound: hexachlorobenzene\nCompound: propranolol\nCompound: propylthiouracil\nCompound: glibenclamide\nCompound: allyl alcohol\nCompound: ethionamide\nCompound: tetracycline\nCompound: carbamazepine\nCompound: enalapril\nCompound: ethinylestradiol\nCompound: haloperidol\nCompound: bucetin\nCompound: ethionine\nCompound: methapyrilene\nCompound: methylene dianiline\nCompound: lornoxicam\nCompound: fluphenazine\nCompound: rifampicin\nCompound: methyldopa\nCompound: phenylanthranilic acid\nCompound: disulfiram\nCompound: quinidine\nCompound: ticlopidine\nCompound: puromycin aminonucleoside\nCompound: promethazine\nCompound: bromobenzene\nCompound: thioridazine\nCompound: ethambutol\nCompound: gemfibrozil\nCompound: diltiazem\nCompound: vitamin A\nCompound: ciprofloxacin\nCompound: phenobarbital\nCompound: methyltestosterone\nCompound: chlorpropamide\nCompound: ibuprofen\nCompound: nifedipine\nCompound: tolbutamide\nCompound: thioacetamide\nCompound: clomipramine\nCompound: bromoethylamine\nCompound: trimethadione\nCompound: coumarin\nCompound: meloxicam\nCompound: chlorpheniramine\nCompound: fenofibrate\nCompound: valproic acid\nCompound: acetazolamide\nCompound: terbinafine\nCompound: triamterene\nCompound: allopurinol\nCompound: amphotericin B\nCompound: desmopressin acetate\nCompound: cephalothin\nCompound: papaverine\nCompound: amitriptyline\nCompound: indomethacin\nCompound: penicilla ...
#  LinearConversation(title='Functional Criteria for Compound Order', create_time=1709851858.42512, update_time=1709852062.470933, mapping={'aaa15694-6345-43a7-be05-1c5b4f73f9f6': Node(id='aaa15694-6345-43a7-be05-1c5b4f73f9f6', message=None, parent=None, children=['dc35e96e-78eb-434f-ad69-2f84416bb49c']), 'aaa2529d-3ccd-4f97-8907-35cddef7bef1': Node(id='aaa2529d-3ccd-4f97-8907-35cddef7bef1', message=Message(id='aaa2529d-3ccd-4f97-8907-35cddef7bef1', author=Author(role='user', name=None, metadata={}), create_time=1709851922.300042, update_time=None, content=Content(content_type='text', parts=['Help me understand why this compounds have this order. I know for certain they have been ordered under a functional criteria, but I do not know which one or which combinations and I need to try to reverse engineer it. \nCompound: fluoxetine hydrochloride\nCompound: labetalol\nCompound: acarbose\nCompound: nicotinic acid\nCompound: ajmaline\nCompound: carboplatin\nCompound: ranitidine\nCompound: benziodarone\nCompound: butylated hydroxyanisole\nCompound: danazol\nCompound: omeprazole\nCompound: chlormadinone\nCompound: WY-14643\nCompound: bendazac\nCompound: simvastatin\nCompound: griseofulvin\nCompound: etoposide\nCompound: nimesulide\nCompound: 2,4-dinitrophenol\nCompound: diclofenac\nCompound: tiopronin\nCompound: famotidine\nCompound: pemoline\nCompound: cyclophosphamide\nCompound: triazolam\nCompound: colchicine\nCompound: dantrolene\nCompound: perhexiline\nCompound: ethanol\nCompound: erythromycin ethylsuccinate\nCompound: lomustine\nCompound: doxorubicin\nCompound: acetamidofluorene\nCompound: tacrine\nCompound: caffeine\nCompound: captopril\nCompound: azathioprine\nCompound: flutamide\nCompound: aspirin\nCompound: carbon tetrachloride\nCompound: nitrofurazone\nCompound: nitrosodiethylamine\nCompound: chlormezanone\nCompound: moxisylyte\nCompound: isoniazid\nCompound: rotenone\nCompound: naphthyl isothiocyanate\nCompound: metformin\nCompound: theophylline\nCompound: sulfasalazine\nCompound: adapin\nCompound: nitrofurantoin\nCompound: sulindac\nCompound: cimetidine\nCompound: sulpiride\nCompound: clofibrate\nCompound: benzbromarone\nCompound: amiodarone\nCompound: rosiglitazone maleate\nCompound: hexachlorobenzene\nCompound: propranolol\nCompound: propylthiouracil\nCompound: glibenclamide\nCompound: allyl alcohol\nCompound: ethionamide\nCompound: tetracycline\nCompound: carbamazepine\nCompound: enalapril\nCompound: ethinylestradiol\nCompound: haloperidol\nCompound: bucetin\nCompound: ethionine\nCompound: methapyrilene\nCompound: methylene dianiline\nCompound: lornoxicam\nCompound: fluphenazine\nCompound: rifampicin\nCompound: methyldopa\nCompound: phenylanthranilic acid\nCompound: disulfiram\nCompound: quinidine\nCompound: ticlopidine\nCompound: puromycin aminonucleoside\nCompound: promethazine\nCompound: bromobenzene\nCompound: thioridazine\nCompound: ethambutol\nCompound: gemfibrozil\nCompound: diltiazem\nCompound: vitamin A\nCompound: ciprofloxacin\nCompound: phenobarbital\nCompound: methyltestosterone\nCompound: chlorpropamide\nCompound: ibuprofen\nCompound: nifedipine\nCompound: tolbutamide\nCompound: thioacetamide\nCompound: clomipramine\nCompound: bromoethylamine\nCompound: trimethadione\nCompound: coumarin\nCompound: meloxicam\nCompound: chlorpheniramine\nCompound: fenofibrate\nCompound: valproic acid\nCompound: acetazolamide\nCompound: terbinafine\nCompound: triamterene\nCompound: allopurinol\nCompound: amphotericin B\nCompound: desmopressin acetate\nCompound: cephalothin\nCompound: papaverine\nCompound: amitriptyline\nCompound: indomethacin\nCompound: penicillamine\nCompound: tamoxifen\nCompound: furosemide\nCompound: chlorpromazine\nCompound: iproniazid\nCompound: hydroxyzine\nCompound: cyclosporine A\nCompound: mexiletine\nCompound: methimazole\nCompound: acetamide\nCompound: chloramphenicol\nCompound: phalloidin\nCompound: disopyramide\nCompound: naproxen\nCompound: monocrotaline\nCompound: phenytoin\nCompound: imipramine\ ...
#  LinearConversation(title='Functional Criteria for Compound Order', create_time=1709851858.42512, update_time=1709852062.470933, mapping={'aaa15694-6345-43a7-be05-1c5b4f73f9f6': Node(id='aaa15694-6345-43a7-be05-1c5b4f73f9f6', message=None, parent=None, children=['dc35e96e-78eb-434f-ad69-2f84416bb49c']), 'aaa2d260-4979-4b5d-acd7-24d658ade059': Node(id='aaa2d260-4979-4b5d-acd7-24d658ade059', message=Message(id='aaa2d260-4979-4b5d-acd7-24d658ade059', author=Author(role='user', name=None, metadata={}), create_time=1709851981.363171, update_time=None, content=Content(content_type='text', parts=['Help me understand why this compounds have this order. I know for certain they have been ordered under a functional criteria, but I do not know which one or which combinations and I need to try to reverse engineer it. \nCompound: fluoxetine hydrochloride\nCompound: labetalol\nCompound: acarbose\nCompound: nicotinic acid\nCompound: ajmaline\nCompound: carboplatin\nCompound: ranitidine\nCompound: benziodarone\nCompound: butylated hydroxyanisole\nCompound: danazol\nCompound: omeprazole\nCompound: chlormadinone\nCompound: WY-14643\nCompound: bendazac\nCompound: simvastatin\nCompound: griseofulvin\nCompound: etoposide\nCompound: nimesulide\nCompound: 2,4-dinitrophenol\nCompound: diclofenac\nCompound: tiopronin\nCompound: famotidine\nCompound: pemoline\nCompound: cyclophosphamide\nCompound: triazolam\nCompound: colchicine\nCompound: dantrolene\nCompound: perhexiline\nCompound: ethanol\nCompound: erythromycin ethylsuccinate\nCompound: lomustine\nCompound: doxorubicin\nCompound: acetamidofluorene\nCompound: tacrine\nCompound: caffeine\nCompound: captopril\nCompound: azathioprine\nCompound: flutamide\nCompound: aspirin\nCompound: carbon tetrachloride\nCompound: nitrofurazone\nCompound: nitrosodiethylamine\nCompound: chlormezanone\nCompound: moxisylyte\nCompound: isoniazid\nCompound: rotenone\nCompound: naphthyl isothiocyanate\nCompound: metformin\nCompound: theophylline\nCompound: sulfasalazine\nCompound: adapin\nCompound: nitrofurantoin\nCompound: sulindac\nCompound: cimetidine\nCompound: sulpiride\nCompound: clofibrate\nCompound: benzbromarone\nCompound: amiodarone\nCompound: rosiglitazone maleate\nCompound: hexachlorobenzene\nCompound: propranolol\nCompound: propylthiouracil\nCompound: glibenclamide\nCompound: allyl alcohol\nCompound: ethionamide\nCompound: tetracycline\nCompound: carbamazepine\nCompound: enalapril\nCompound: ethinylestradiol\nCompound: haloperidol\nCompound: bucetin\nCompound: ethionine\nCompound: methapyrilene\nCompound: methylene dianiline\nCompound: lornoxicam\nCompound: fluphenazine\nCompound: rifampicin\nCompound: methyldopa\nCompound: phenylanthranilic acid\nCompound: disulfiram\nCompound: quinidine\nCompound: ticlopidine\nCompound: puromycin aminonucleoside\nCompound: promethazine\nCompound: bromobenzene\nCompound: thioridazine\nCompound: ethambutol\nCompound: gemfibrozil\nCompound: diltiazem\nCompound: vitamin A\nCompound: ciprofloxacin\nCompound: phenobarbital\nCompound: methyltestosterone\nCompound: chlorpropamide\nCompound: ibuprofen\nCompound: nifedipine\nCompound: tolbutamide\nCompound: thioacetamide\nCompound: clomipramine\nCompound: bromoethylamine\nCompound: trimethadione\nCompound: coumarin\nCompound: meloxicam\nCompound: chlorpheniramine\nCompound: fenofibrate\nCompound: valproic acid\nCompound: acetazolamide\nCompound: terbinafine\nCompound: triamterene\nCompound: allopurinol\nCompound: amphotericin B\nCompound: desmopressin acetate\nCompound: cephalothin\nCompound: papaverine\nCompound: amitriptyline\nCompound: indomethacin\nCompound: penicillamine\nCompound: tamoxifen\nCompound: furosemide\nCompound: chlorpromazine\nCompound: iproniazid\nCompound: hydroxyzine\nCompound: cyclosporine A\nCompound: mexiletine\nCompound: methimazole\nCompound: acetamide\nCompound: chloramphenicol\nCompound: phalloidin\nCompound: disopyramide\nCompound: naproxen\nCompound: monocrotaline\nCompound: phenytoin\nCompound: imipramine\ ...
#  LinearConversation(title='Functional Criteria for Compound Order', create_time=1709851858.42512, update_time=1709852062.470933, mapping={'aaa15694-6345-43a7-be05-1c5b4f73f9f6': Node(id='aaa15694-6345-43a7-be05-1c5b4f73f9f6', message=None, parent=None, children=['dc35e96e-78eb-434f-ad69-2f84416bb49c']), 'aaa270c8-9410-41ff-a995-8ced8fa2891c': Node(id='aaa270c8-9410-41ff-a995-8ced8fa2891c', message=Message(id='aaa270c8-9410-41ff-a995-8ced8fa2891c', author=Author(role='user', name=None, metadata={}), create_time=1709852031.763697, update_time=None, content=Content(content_type='text', parts=['Help me understand why this compounds have this order. I know for certain they have been ordered under a functional criteria, but I do not know which one or which combinations and I need to try to reverse engineer it. \nCompound: fluoxetine hydrochloride\nCompound: labetalol\nCompound: acarbose\nCompound: nicotinic acid\nCompound: ajmaline\nCompound: carboplatin\nCompound: ranitidine\nCompound: benziodarone\nCompound: butylated hydroxyanisole\nCompound: danazol\nCompound: omeprazole\nCompound: chlormadinone\nCompound: WY-14643\nCompound: bendazac\nCompound: simvastatin\nCompound: griseofulvin\nCompound: etoposide\nCompound: nimesulide\nCompound: 2,4-dinitrophenol\nCompound: diclofenac\nCompound: tiopronin\nCompound: famotidine\nCompound: pemoline\nCompound: cyclophosphamide\nCompound: triazolam\nCompound: colchicine\nCompound: dantrolene\nCompound: perhexiline\nCompound: ethanol\nCompound: erythromycin ethylsuccinate\nCompound: lomustine\nCompound: doxorubicin\nCompound: acetamidofluorene\nCompound: tacrine\nCompound: caffeine\nCompound: captopril\nCompound: azathioprine\nCompound: flutamide\nCompound: aspirin\nCompound: carbon tetrachloride\nCompound: nitrofurazone\nCompound: nitrosodiethylamine\nCompound: chlormezanone\nCompound: moxisylyte\nCompound: isoniazid\nCompound: rotenone\nCompound: naphthyl isothiocyanate\nCompound: metformin\nCompound: theophylline\nCompound: sulfasalazine\nCompound: adapin\nCompound: nitrofurantoin\nCompound: sulindac\nCompound: cimetidine\nCompound: sulpiride\nCompound: clofibrate\nCompound: benzbromarone\nCompound: amiodarone\nCompound: rosiglitazone maleate\nCompound: hexachlorobenzene\nCompound: propranolol\nCompound: propylthiouracil\nCompound: glibenclamide\nCompound: allyl alcohol\nCompound: ethionamide\nCompound: tetracycline\nCompound: carbamazepine\nCompound: enalapril\nCompound: ethinylestradiol\nCompound: haloperidol\nCompound: bucetin\nCompound: ethionine\nCompound: methapyrilene\nCompound: methylene dianiline\nCompound: lornoxicam\nCompound: fluphenazine\nCompound: rifampicin\nCompound: methyldopa\nCompound: phenylanthranilic acid\nCompound: disulfiram\nCompound: quinidine\nCompound: ticlopidine\nCompound: puromycin aminonucleoside\nCompound: promethazine\nCompound: bromobenzene\nCompound: thioridazine\nCompound: ethambutol\nCompound: gemfibrozil\nCompound: diltiazem\nCompound: vitamin A\nCompound: ciprofloxacin\nCompound: phenobarbital\nCompound: methyltestosterone\nCompound: chlorpropamide\nCompound: ibuprofen\nCompound: nifedipine\nCompound: tolbutamide\nCompound: thioacetamide\nCompound: clomipramine\nCompound: bromoethylamine\nCompound: trimethadione\nCompound: coumarin\nCompound: meloxicam\nCompound: chlorpheniramine\nCompound: fenofibrate\nCompound: valproic acid\nCompound: acetazolamide\nCompound: terbinafine\nCompound: triamterene\nCompound: allopurinol\nCompound: amphotericin B\nCompound: desmopressin acetate\nCompound: cephalothin\nCompound: papaverine\nCompound: amitriptyline\nCompound: indomethacin\nCompound: penicillamine\nCompound: tamoxifen\nCompound: furosemide\nCompound: chlorpromazine\nCompound: iproniazid\nCompound: hydroxyzine\nCompound: cyclosporine A\nCompound: mexiletine\nCompound: methimazole\nCompound: acetamide\nCompound: chloramphenicol\nCompound: phalloidin\nCompound: disopyramide\nCompound: naproxen\nCompound: monocrotaline\nCompound: phenytoin\nCompound: imipramine\ ...

# %%
test_instance.visualize_conversation()

# %%
import erdantic as erd

# %%
erd.draw(Conversation, out = 'gang.png')
